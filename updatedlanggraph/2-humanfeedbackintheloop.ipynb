# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
from langchain.chat_models import init_chat_model
llm=init_chat_model("groq:qwen/qwen3-32b")
llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11'}}, output_version=None, profile={'name': 'Qwen3 32B', 'release_date': '2024-12-23', 'last_updated': '2024-12-23', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 40960, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000023FAEC9E290>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000023FAEDE9870>, model_name='qwen/qwen3-32b', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
from typing import Annotated

from langchain_tavily import TavilySearch
from langchain_core.tools import tool
from typing_extensions import TypedDict

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition

from langgraph.types import Command, interrupt

class State(TypedDict):
    messages: Annotated[list, add_messages]

graph_builder = StateGraph(State)

@tool
def human_assistance(query: str) -> str:
    """Request assistance from a human."""
    human_response = interrupt({"query": query})
    return human_response["data"]

tool = TavilySearch(max_results=2)
tools = [tool, human_assistance]
llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    message = llm_with_tools.invoke(state["messages"])
    # Because we will be interrupting during tool execution,
    # we disable parallel tool calling to avoid repeating any
    # tool invocations when we resume.
    
    return {"messages": [message]}

graph_builder.add_node("chatbot", chatbot)

tool_node = ToolNode(tools=tools)
graph_builder.add_node("tools", tool_node)

graph_builder.add_conditional_edges(
    "chatbot",
    tools_condition,
)
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# %%
memory = MemorySaver()

graph = graph_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
user_input = "I need some expert guidance and assistance for building an AI agent. Could you request assistance for me?"
config = {"configurable": {"thread_id": "1"}}

events = graph.stream(
    {"messages": user_input},
    config,
    stream_mode="values",
)
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# I need some expert guidance and assistance for building an AI agent. Could you request assistance for me?
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (mk5mr783a)
#  Call ID: mk5mr783a
#   Args:
#     query: I need expert guidance and assistance for building an AI agent. Could you provide detailed recommendations, best practices, and resources for developing an AI agent, including considerations for architecture, training, deployment, and ethical implications?
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (mk5mr783a)
#  Call ID: mk5mr783a
#   Args:
#     query: I need expert guidance and assistance for building an AI agent. Could you provide detailed recommendations, best practices, and resources for developing an AI agent, including considerations for architecture, training, deployment, and ethical implications?

# %%
human_response = (
    "We, the experts are here to help! We'd recommend you check out LangGraph to build your agent."
    " It's much more reliable and extensible than simple autonomous agents."
)

human_command = Command(resume={"data": human_response})

events = graph.stream(human_command, config, stream_mode="values")
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (mk5mr783a)
#  Call ID: mk5mr783a
#   Args:
#     query: I need expert guidance and assistance for building an AI agent. Could you provide detailed recommendations, best practices, and resources for developing an AI agent, including considerations for architecture, training, deployment, and ethical implications?
# ================================= Tool Message =================================
# Name: human_assistance
#
# We, the experts are here to help! We'd recommend you check out LangGraph to build your agent. It's much more reliable and extensible than simple autonomous agents.
# ================================== Ai Message ==================================
#
# Here's a detailed breakdown of building an AI agent using **LangGraph**, as recommended by our experts:
#
# ---
#
# ### **Why LangGraph?**
# LangGraph is a **modular, stateful, and scalable framework** designed for building advanced AI agents. It addresses limitations of simple autonomous agents by offering:
# 1. **Reliability**: Structured workflows reduce errors in complex agent interactions.
# 2. **Extensibility**: Easily integrate tools, memory systems, and LLMs (e.g., via LangChain).
# 3. **Control**: Define precise execution logic for agent behavior.
#
# ---
#
# ### **Key Features for Building AI Agents**
# 1. **Modular Architecture**
#    - Break down agent workflows into reusable components (e.g., decision nodes, action nodes).
#    - Example: Use `Graph` to define a sequence of tasks like data retrieval, reasoning, and response generation.
#
# 2. **State Management**
#    - Maintain context across interactions using built-in state handling.
#    - Example: Track user session data or agent-specific variables.
#
# 3. **Integration with LangChain**
#    - Leverage LangChain's ecosystem for tools (e.g., databases, APIs) and prompts.
#    - Combine with LLMs like GPT-4 for advanced reasoning.
#
# 4. **Scalability**
#    - Deploy agents in production environments with support for parallel execution and rate limiting.
#
# 5. **Community & Documentation**
#    - Active open-source community and comprehensive guides for rapid prototyping.
#
# ---
#
# ### **Steps to Get Started**
# 1. **Install LangGraph**
#    ```bash
#    pip install langgraph
#    ```
#
# 2. **Define a Basic Agent Workflow**
#    Use the `Graph` API to create a simple agent:
#    ```python
#    from langgraph.graph import Graph, State
#
#    class AgentState(State):
#        input: str
#        output: str
#
#    def agent_node(state: AgentState) -> AgentState:
#        # Example logic (replace with LLM or tool calls)
#        state.output = f"Processed: {state.input}"
#        return state
#
#    workflow = Graph()
#    workflow.add_node("agent", agent_node)
#    workflow.set_entry_point("agent")
#    app = workflow.compile()
#
#    result = app.invoke({"input": "Hello, world!"})
#    print(result["output"])  # Output: "Processed: Hello, world!"
#    ```
#
# 3. **Expand with Tools**
#    Integrate tools like `TavilySearch` (for real-time data) or `SQLDatabase` for persistent storage.
#
# 4. **Deploy**
#    Use LangGraph's serverless deployment options or integrate with cloud platforms (AWS, GCP).
#
# ---
#
# ### **Ethical Considerations**
# - **Bias Mitigation**: Audit agent outputs using fairness tools (e.g., `Fairlearn`).
# - **Transparency**: Implement logging and explainability layers.
# - **Security**: Restrict agent access to sensitive data via role-based controls.
#
# ---
#
# Would you like deeper guidance on any specific aspect (e.g., training pipelines, ethical frameworks, or deployment strategies)? Let me know! 🤖
