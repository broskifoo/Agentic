# %% [markdown]
# https://colab.research.google.com/drive/1SVjvgqvKfF-FPAIqpEZdKMQLhe13NLFD

# %% [markdown]
# the google collab link for all the souce codes from the lecture agentic ai in 10 hours by Krish naik at 8:02 hours

# %% [markdown]
# ![image.png](attachment:image.png)
